# %% [markdown]
# <a href="https://colab.research.google.com/github/andrewdevine2/MIS2800/blob/main/HW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### The next six blocks provide the exact code to run to get your Colab file started to run SQLite3

# %%
# Type this code exactly as shown to intall the first library needed for
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 94.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 67.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: prettytable
#     Found existing installation: prettytable 3.17.0
#     Uninstalling prettytable-3.17.0:
#       Successfully uninstalled prettytable-3.17.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.0 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.0 which is incompatible.
# ...

# %%
# Install the SQL extension. Remember to type exactly as shown here.
# !pip install ipython-sql
print("ipython sql installed")
# Out:
# ...
# ipython sql installed

# %%
# Load the SQL magic extension
# %load_ext sql

# %%
#this code imports sqlite3 and prints a statement stating it has been im
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
# This creates a brand-new, empty database file named 'AdCampaigns2026.d
conn = sqlite3.connect('AdCampaigns2026.db')
print("database created")
# Out:
# database created

# %%
# This line is required so Colab stops acting like Python and acts more
# %sql sqlite:///AdCampaigns2026.db

# %% [markdown]
# ### There are bugs (mistakes) for you to find and fix in the next 10 blocks

# %%
#Block 1
# Instructions: There is a typo in the table.  Hint: a word is missing.
# %%sql
CREATE TABLE Marketing_Brands (
  brand_id INTEGER PRIMARY KEY,
  brand_name TEXT,
  brand_type TEXT,
  brand_budget INTEGER
) STRICT;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# []

# %%
#Block 2
# Instructions: Find and fix the error.
# %%sql
INSERT INTO Marketing_Brands (brand_id, brand_name, brand_type, brand_budget)
VALUES
  (1, 'Doritos', 'Snacks', 7000000),
  (2, 'AWS', 'Technology', 15000000),
  (3, 'Pepsi', 'Beverages', 2000000),
  (4, 'He_Gets_Us', 'Religious', 1000000),
  (5, 'Dr_Pepper', 'Beverages', 5000000),
  (6, 'IBM', 'Technology', 100000),
  (7, 'Google', 'Technology', 8000000);
# Out:
#  * sqlite:///AdCampaigns2026.db
# 7 rows affected.
# []

# %%
#Block 3
# %%sql
-- Instructions: Fix the code to select all the columns from the Marketi
SELECT * FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (6, 'IBM', 'Technology', 100000),
#  (7, 'Google', 'Technology', 8000000)]

# %%
#Block 4
# %%sql
-- Instructions: Fix the code to display only the brand names and brand
SELECT brand_name, brand_type
FROM marketing_brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos', 'Snacks'),
#  ('AWS', 'Technology'),
#  ('Pepsi', 'Beverages'),
#  ('He_Gets_Us', 'Religious'),
#  ('Dr_Pepper', 'Beverages'),
#  ('IBM', 'Technology'),
#  ('Google', 'Technology')]

# %%
#Block 5
# %%sql
-- Instructions: Fix the code to find the brand types that are Religious
SELECT * FROM Marketing_Brands
WHERE brand_type = 'Religious'
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(4, 'He_Gets_Us', 'Religious', 1000000)]

# %%
#Block 6
# %%sql
-- Instructions: Fix the code to display the brand names that have a bud
SELECT brand_name FROM Marketing_Brands
WHERE brand_budget > 5000000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos',), ('AWS',), ('Google',)]

# %%
#Block 7
# %%sql
-- Instructins: Fix the code so that this will run SQLite3 in Colab witho
SELECT * FROM Marketing_Brands
WHERE brand_budget > 7000000
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(2, 'AWS', 'Technology', 15000000), (7, 'Google', 'Technology', 8000000)]

# %%
#Block 8
# %%sql
--Instructions: Find the brands where the brand type is Snacks or Bevera
SELECT * FROM Marketing_Brands
WHERE brand_type = 'Snacks' OR 'Beverages'
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000)]

# %%
#Block 9
# %%sql
-- Instructions: Sort the table by brand budget in DESC order. Display o
SELECT brand_name, brand_budget FROM marketing_brands
ORDER BY brand_budget DESC
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('AWS', 15000000),
#  ('Google', 8000000),
#  ('Doritos', 7000000),
#  ('Dr_Pepper', 5000000),
#  ('Pepsi', 2000000),
#  ('He_Gets_Us', 1000000),
#  ('IBM', 100000)]

# %%
#Block 10
# Using SQLite3 (and all its magic) to create a table showing all the code
# %%sql
SELECT * FROM sqlite_master
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('table', 'Marketing_Brands', 'Marketing_Brands', 2, 'CREATE TABLE Marketing_Brands (\n  brand_id INTEGER PRIMARY KEY,\n  brand_name TEXT,\n  brand_type TEXT,\n  brand_budget INTEGER\n) STRICT')]

# %% [markdown]
# ### Answer the Questions Below Based Based on the SQL Code You've Run Above
#
#   1. How did you fix the error in block #1? Answer: I added the missing TABLE keyword to the CREATE statement.
#   2. How did you fix the error in block #2? Answer:I added INTO Marketing_Brands after INSERT so the table was specified.
#   3. How did you fix the error in block #3? Answer: I added * to the SELECT statement to select all columns.
#   4. How did you fix the error in block #4? Answer:I specified the column names brand_name and brand_type in the SELECT clause.
#   5. How did you fix the error in block #5? Answer: I added a WHERE clause to filter rows where brand_type equals Religious.
#   6. How did you fix the error in block #6? Answer: I selected brand_name and added a WHERE condition using brand_budget.
#   7. How did you fix the error in block #7? Answer: I removed the extra %%sql and made sure the table was created before running the query.
#   8. How did you fix the error in block #8? Answer: I added a WHERE clause using OR to filter Snacks or Beverages.
#   9. How did you fix the error in block #9? Answer: I completed the query with FROM Marketing_Brands and ORDER BY brand_budget DESC.
#   10. How did you fix the error in block #10? Answer: I answered each question using the corrected SQL logic from the previous blocks.
